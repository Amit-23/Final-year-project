# %%
import pandas as pd
import numpy as np
from math import log2
import math

def shannon_entropy(x):
    """
    Calculate the Shannon entropy of a feature.
    """
    counts = np.bincount(x)
    probs = counts / len(x)
    entropy = -np.sum(probs * np.log2(probs))
    return entropy

def feature_ranking(df, target_col):
    """
    Rank the features in a DataFrame using Shannon's entropy.
    """
    #features = df.drop(target_col, axis=1).columns
    features = df.copy()
    rankings = {}
    for feature in features:
        x = df[feature].values
        y = df[target_col].values
        mutual_info = shannon_entropy(y) - shannon_entropy(y[x])
        rankings[feature] = mutual_info
    rankings = {k: v for k, v in sorted(rankings.items(), key=lambda item: item[1], reverse=True)}
    return rankings

# Example usage
df = pd.read_csv('final.csv')
rankings = feature_ranking(df, 'target')
print(rankings)
# Out:
# C:\Users\amit\AppData\Local\Temp\ipykernel_12800\1659029405.py:12: RuntimeWarning: divide by zero encountered in log2
#   entropy = -np.sum(probs * np.log2(probs))
# C:\Users\amit\AppData\Local\Temp\ipykernel_12800\1659029405.py:12: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(probs * np.log2(probs))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 32>()
#      30 # Example usage
#      31 df = pd.read_csv('final.csv')
# ---> 32 rankings = feature_ranking(df, 'target')
#      33 print(rankings)
#
# Input In [3], in feature_ranking(df, target_col)
#      23     x = df[feature].values
#      24     y = df[target_col].values
# ---> 25     mutual_info = shannon_entropy(y) - shannon_entropy(y[x])
#      26     rankings[feature] = mutual_info
#      27 rankings = {k: v for k, v in sorted(rankings.items(), key=lambda item: item[1], reverse=True)}
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
from datetime import date

def entropy(data):
    """Calculates Shannon's entropy for a given distribution"""
    # Compute the frequency of each class label
    value_counts = data.value_counts()
    # Compute the probability of each class label
    probabilities = value_counts / len(data)
    # Compute the entropy
    entropy = sum(-p * math.log2(p) for p in probabilities)
    return entropy

def feature_ranking(features, target):
    """
    Computes the feature ranking vector using Shannon's entropy as the scoring function.

    Args:
        features: A pandas dataframe containing the features.
        target: A pandas series containing the target variable.

    Returns:
        A pandas series containing the feature weights (in descending order).
    """
    feature_weights = {}
    for feature in features.columns:
        if feature not in ['id','index','text','user_id','created_at','url','expanded_url']:
            #feature_score = features.groupby(feature)[target]
            print(features.groupby(feature))
            feature_score = entropy(features.groupby(feature).apply(entropy))
            feature_weights[feature] = feature_score
    
    total_score = sum(feature_weights.values())
    feature_weights = {k: v/total_score for k, v in feature_weights.items()}
    
    return pd.Series(feature_weights).sort_values(ascending=False)

data = pd.read_csv('final.csv')

data = data.drop(range(30,len(data))) #take only the first 30 data

# Split the dataset into features and target
features = data.drop('target', axis=1)
target = data['target']

# Compute the feature weights using Shannon's entropy
feature_weights = feature_ranking(features, target)

# Print the feature weights
print(feature_weights)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E15F66BEE0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000
# 32  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 33  http://www.muzu.tv/spandau-ballet/gold-music-v...        404.0
# 34                           https://www.virgilio.it/        200.0
# 35  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 36  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 37                                                NaN          NaN
# 38  http://www.muzu.tv/musica-degli-anni-80/falco-...        404.0
# 39   https://www.scuola-pizzaioli.com/it/master-pizza        200.0
# 40  https://www.youtube.com/watch?v=0S9X1DfLJ7U&fe...        200.0
# 41  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 42  https://www.youtube.com/watch?v=_nLIBMNwi8M&fe...        200.0
# 43  https://www.youtube.com/watch?v=btPJPFnesV4&it...        200.0
# 44  http://www.beezer.it/2014/11/07/10-cose-non-sa...        200.0
# 45  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 46  https://ricette.donnamoderna.com/minestra-di-c...        200.0
# 47  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 48  https://www.facebook.com/photo.php?fbid=102053...        200.0
# 49  http://www.muzu.tv/musicadeglianni80/vasco-ros...        404.0
# 50        https://www.youtube.com/watch?v=QUvmq2lkrHM        200.0
# 51  https://www.buttalapasta.it/articolo/secondi-p...        404.0
# 52  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 53  http://www.muzu.tv/musicadeglianni80/tiziana-r...        404.0
# 54  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 55  https://www.runnersworld.it/un-mare-di-salute-...        410.0
# 56  https://www.facebook.com/Davideb66/posts/10205...        200.0
# 57             https://publishers.dailymotion.com/en/        200.0
# 58  https://www.youtube.com/watch?v=n_pLleIU41A&it...        200.0
#
#     is_@_present  is___present  is_#_present  is_redirected  \
# 0          False          True         False           True
# 1          False         False         False           True
# 2          False         False         False           True
# 3          False         False         False           True
# 4          False         False         False           True
# 5          False         False         False           True
# 6          False         False         False           True
# 7          False         False         False           True
# 8          False         False         False          False
# 9          False         False         False           True
# 10         False         False         False           True
# 11         False         False         False           True
# 12         False         False         False           True
# 13         False          True         False           True
# 14         False         False         False           True
# 15         False         False         False           True
# 16         False         False         False           True
# 17         False         False         False           True
# 18         False         False         False           True
# 19         False         False         False           True
# 20         False         False         False           True
# 21         False         False         False           True
# 22         False         False         False           True
# 23         False         False         False           True
# 24         False         False         False           True
# 25         False         False         False           True
# 26         False         False         False           True
# 27         False         False         False           True
# 28         False         False         False           True
# 29         False          True         False           True
# 30         False         False         False           True
# 31         False         False         False           True
# 32         False         False         False           True
# 33         False         False         False           True
# 34         False         False         False           True
# 35         False         False         False           True
# 36         False         False         False           True
# 37         False         False         False          False
# 38         False         False         False           True
# 39         False         False         False           True
# 40         False         False         False           True
# 41         False         False         False           True
# 42         False          True         False           True
# 43         False         False         False           True
# 44         False         False         False           True
# 45         False         False         False           True
# 46         False         False         False           True
# 47         False         False         False           True
# 48         False         False         False           True
# 49         False         False         False           True
# 50         False         False         False           True
# 51         False         False         False           True
# 52         False         False         False           True
# 53         False         False         False           True
# 54         False         False         False           True
# 55         False         False         False           True
# 56         False         False         False           True
# 57         False         False         False           True
# 58         False          True         False           True
#
#     number_of_redirects  error_fetch  page_rank  is_abnormal  target  \
# 0                     3        False      10.00        False       1
# 1                     3        False      10.00        False       1
# 2                     5        False       2.72        False       1
# 3                     3        False      10.00        False       1
# 4                     3        False       5.03        False       1
# 5                     5        False       4.72        False       1
# 6                     3        False      10.00        False       1
# 7                     3        False      10.00        False       1
# 8                     0         True        NaN        False       1
# 9                     3        False       5.03        False       1
# 10                    6        False       2.68        False       1
# 11                    5        False      10.00        False       1
# 12                    3        False      10.00        False       1
# 13                    5        False      10.00        False       1
# 14                    3        False      10.00        False       1
# 15                    5        False       3.11        False       1
# 16                    3        False      10.00        False       1
# 17                    4        False       4.20        False       1
# 18                    3        False      10.00        False       1
# 19                    3        False      10.00        False       1
# 20                    3        False       5.03        False       1
# 21                    4        False      10.00        False       1
# 22                    4        False       4.52        False       1
# 23                    3        False      10.00        False       1
# 24                    3        False       5.03        False       1
# 25                    3        False      10.00        False       1
# 26                    4        False       4.47        False       1
# 27                    3        False      10.00        False       1
# 28                    8        False       4.15        False       1
# 29                    3        False      10.00        False       1
# 30                    3        False      10.00        False       1
# 31                    5        False       2.72        False       1
# 32                    3        False      10.00        False       1
# 33                    3        False       5.03        False       1
# 34                    5        False       4.72        False       1
# 35                    3        False      10.00        False       1
# 36                    3        False      10.00        False       1
# 37                    0         True        NaN        False       1
# 38                    3        False       5.03        False       1
# 39                    6        False       2.68        False       1
# 40                    5        False      10.00        False       1
# 41                    3        False      10.00        False       1
# 42                    5        False      10.00        False       1
# 43                    3        False      10.00        False       1
# 44                    5        False       3.11        False       1
# 45                    3        False      10.00        False       1
# 46                    4        False       4.20        False       1
# 47                    3        False      10.00        False       1
# 48                    3        False      10.00        False       1
# 49                    3        False       5.03        False       1
# 50                    4        False      10.00        False       1
# 51                    4        False       4.52        False       1
# 52                    3        False      10.00        False       1
# 53                    3        False       5.03        False       1
# 54                    3        False      10.00        False       1
# 55                    4        False       4.47        False       1
# 56                    3        False      10.00        False       1
# 57                    8        False       4.15        False       1
# 58                    3        False      10.00        False       1
#
#     expiration_days_left
# 0                  324.0
# 1                 2924.0
# 2                  288.0
# 3                 2924.0
# 4                    NaN
# 5                   43.0
# 6                 2924.0
# 7                 2924.0
# 8                    NaN
# 9                    NaN
# 10                 296.0
# 11                 324.0
# 12                2924.0
# 13                 324.0
# 14                 324.0
# 15                 103.0
# 16                2924.0
# 17                 158.0
# 18                2924.0
# 19                2924.0
# 20                   NaN
# 21                 324.0
# 22                  91.0
# 23                2924.0
# 24                   NaN
# 25                2924.0
# 26                 312.0
# 27                2924.0
# 28                1084.0
# 29                 324.0
# 30                2924.0
# 31                 288.0
# 32                2924.0
# 33                   NaN
# 34                  43.0
# 35                2924.0
# 36                2924.0
# 37                   NaN
# 38                   NaN
# 39                 296.0
# 40                 324.0
# 41                2924.0
# 42                 324.0
# 43                 324.0
# 44                 103.0
# 45                2924.0
# 46                 158.0
# 47                2924.0
# 48                2924.0
# 49                   NaN
# 50                 324.0
# 51                  91.0
# 52                2924.0
# 53                   NaN
# 54                2924.0
# 55                 312.0
# 56                2924.0
# 57                1084.0
# 58                 324.0

# %%
input_data = data.copy()
input_data = input_data.drop(['index','id', 'text', 'created_at', 'url', 'expanded_url'],axis = 1)

# df['Set_of_Numbers'] = df['Set_of_Numbers'].fillna(0)

input_data = input_data.dropna()
input_data
# Out:
#      user_id  http_status  is_@_present  is___present  is_#_present  \
# 0   24858289        200.0         False          True         False
# 1   24858289        200.0         False         False         False
# 2   24858289        200.0         False         False         False
# 3   24858289        200.0         False         False         False
# 5   24858289        200.0         False         False         False
# 6   24858289        200.0         False         False         False
# 7   24858289        200.0         False         False         False
# 10  24858289        200.0         False         False         False
# 11  24858289        200.0         False         False         False
# 12  24858289        200.0         False         False         False
# 13  24858289        200.0         False          True         False
# 14  24858289        200.0         False         False         False
# 15  24858289        200.0         False         False         False
# 16  24858289        200.0         False         False         False
# 17  24858289        200.0         False         False         False
# 18  24858289        200.0         False         False         False
# 19  24858289        200.0         False         False         False
# 21  24858289        200.0         False         False         False
# 22  24858289        404.0         False         False         False
# 23  24858289        200.0         False         False         False
# 25  24858289        200.0         False         False         False
# 26  24858289        410.0         False         False         False
# 27  24858289        200.0         False         False         False
# 28  24858289        200.0         False         False         False
# 29  24858289        200.0         False          True         False
# 30  24858289        200.0         False         False         False
# 31  24858289        200.0         False         False         False
# 32  24858289        200.0         False         False         False
# 34  24858289        200.0         False         False         False
# 35  24858289        200.0         False         False         False
# 36  24858289        200.0         False         False         False
# 39  24858289        200.0         False         False         False
# 40  24858289        200.0         False         False         False
# 41  24858289        200.0         False         False         False
# 42  24858289        200.0         False          True         False
# 43  24858289        200.0         False         False         False
# 44  24858289        200.0         False         False         False
# 45  24858289        200.0         False         False         False
# 46  24858289        200.0         False         False         False
# 47  24858289        200.0         False         False         False
# 48  24858289        200.0         False         False         False
# 50  24858289        200.0         False         False         False
# 51  24858289        404.0         False         False         False
# 52  24858289        200.0         False         False         False
# 54  24858289        200.0         False         False         False
# 55  24858289        410.0         False         False         False
# 56  24858289        200.0         False         False         False
# 57  24858289        200.0         False         False         False
# 58  24858289        200.0         False          True         False
#
#     is_redirected  number_of_redirects  error_fetch  page_rank  is_abnormal  \
# 0            True                    3        False      10.00        False
# 1            True                    3        False      10.00        False
# 2            True                    5        False       2.72        False
# 3            True                    3        False      10.00        False
# 5            True                    5        False       4.72        False
# 6            True                    3        False      10.00        False
# 7            True                    3        False      10.00        False
# 10           True                    6        False       2.68        False
# 11           True                    5        False      10.00        False
# 12           True                    3        False      10.00        False
# 13           True                    5        False      10.00        False
# 14           True                    3        False      10.00        False
# 15           True                    5        False       3.11        False
# 16           True                    3        False      10.00        False
# 17           True                    4        False       4.20        False
# 18           True                    3        False      10.00        False
# 19           True                    3        False      10.00        False
# 21           True                    4        False      10.00        False
# 22           True                    4        False       4.52        False
# 23           True                    3        False      10.00        False
# 25           True                    3        False      10.00        False
# 26           True                    4        False       4.47        False
# 27           True                    3        False      10.00        False
# 28           True                    8        False       4.15        False
# 29           True                    3        False      10.00        False
# 30           True                    3        False      10.00        False
# 31           True                    5        False       2.72        False
# 32           True                    3        False      10.00        False
# 34           True                    5        False       4.72        False
# 35           True                    3        False      10.00        False
# 36           True                    3        False      10.00        False
# 39           True                    6        False       2.68        False
# 40           True                    5        False      10.00        False
# 41           True                    3        False      10.00        False
# 42           True                    5        False      10.00        False
# 43           True                    3        False      10.00        False
# 44           True                    5        False       3.11        False
# 45           True                    3        False      10.00        False
# 46           True                    4        False       4.20        False
# 47           True                    3        False      10.00        False
# 48           True                    3        False      10.00        False
# 50           True                    4        False      10.00        False
# 51           True                    4        False       4.52        False
# 52           True                    3        False      10.00        False
# 54           True                    3        False      10.00        False
# 55           True                    4        False       4.47        False
# 56           True                    3        False      10.00        False
# 57           True                    8        False       4.15        False
# 58           True                    3        False      10.00        False
#
#     target  expiration_days_left
# 0        1                 324.0
# 1        1                2924.0
# 2        1                 288.0
# 3        1                2924.0
# 5        1                  43.0
# 6        1                2924.0
# 7        1                2924.0
# 10       1                 296.0
# 11       1                 324.0
# 12       1                2924.0
# 13       1                 324.0
# 14       1                 324.0
# 15       1                 103.0
# 16       1                2924.0
# 17       1                 158.0
# 18       1                2924.0
# 19       1                2924.0
# 21       1                 324.0
# 22       1                  91.0
# 23       1                2924.0
# 25       1                2924.0
# 26       1                 312.0
# 27       1                2924.0
# 28       1                1084.0
# 29       1                 324.0
# 30       1                2924.0
# 31       1                 288.0
# 32       1                2924.0
# 34       1                  43.0
# 35       1                2924.0
# 36       1                2924.0
# 39       1                 296.0
# 40       1                 324.0
# 41       1                2924.0
# 42       1                 324.0
# 43       1                 324.0
# 44       1                 103.0
# 45       1                2924.0
# 46       1                 158.0
# 47       1                2924.0
# 48       1                2924.0
# 50       1                 324.0
# 51       1                  91.0
# 52       1                2924.0
# 54       1                2924.0
# 55       1                 312.0
# 56       1                2924.0
# 57       1                1084.0
# 58       1                 324.0

# %%
y = input_data['target'].values
columns_needed = list(input_data.columns)
columns_needed.remove('target')

x = input_data[columns_needed].values

# %%
colum = (column - np.avg(colum))/np.std(colum)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y ,
                                   random_state=104, 
                                   test_size=0.25, 
                                   shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
# ----> 3 x_train, x_test,
#       4 y_train, y_test = train_test_split(x,y ,
#       5                                    random_state=104,
#       6                                    test_size=0.25,
#       7                                    shuffle=True)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test,y_test)

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)

# %%
from sklearn import matrics
import matplotlib.pyplot as plt

confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
